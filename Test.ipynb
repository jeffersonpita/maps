# %%
import pandas as pd

education_df = pd.read_csv("SYB62_T09_201905_Public Expenditure on Education.csv")

# %%
education_df
# Out:
#                       T09 Public expenditure on education Unnamed: 2  \
# 0     Region/Country/Area                             NaN       Year
# 1                       4                     Afghanistan       2010
# 2                       4                     Afghanistan       2010
# 3                       4                     Afghanistan       2010
# 4                       4                     Afghanistan       2010
# 5                       4                     Afghanistan       2010
# 6                       4                     Afghanistan       2010
# 7                       4                     Afghanistan       2010
# 8                       4                     Afghanistan       2010
# 9                       4                     Afghanistan       2015
# 10                      4                     Afghanistan       2015
# 11                      4                     Afghanistan       2015
# 12                      4                     Afghanistan       2015
# ...
